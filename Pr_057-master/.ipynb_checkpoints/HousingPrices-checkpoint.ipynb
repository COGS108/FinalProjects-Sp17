# %% [markdown]
# # Housing Prices

# %% [markdown]
# notebook by Lauren Liao

# %%
# imports
import numpy as np
import pandas as pd
import scipy as sp
import scipy.io as io
import scipy.signal as sig
import math as math
import random 
from scipy import integrate
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
plt.style.use('seaborn-colorblind')
plt.rcParams['image.cmap'] = 'RdBu'

# %% [markdown]
# ## 1. Clean data

# %%
# grabbing data
path = 'C:/Users/Lauren/COGS108/HousingPrices.csv'
df = pd.read_csv(path)
print(df.keys())
# Out:
# Index(['Area', 'Category', 'Units', 'Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May',
#        'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Avg'],
#       dtype='object')

# %% [markdown]
# Data information
# > This database reports the number of sales, average sales price, average price per square foot, and average square footage of all homes, condos/townhouses, and single-family homes.
# Home sales excludes quitclaims and foreclosures and transactions with no price and no loan
# Average or median prices exclude multi-property sales, where more than one property was included in a single sale with a single price
#
# >Prices marked as partial are also excluded
# Average and median price per square foot calculations use every sale were a full price and square footage was known and calculates
# Square footage reflects the square footage of the living area of all structures on the property (excluding the garage or patio)
# Each county uses a set of codes to identify condos and townhomes, and these are standardized
# Prices are unadjusted for inflation.
# - See more at: http://www.randstatestats.org/ca/stats/housing-prices-and-transactions-(ca-only).html#sthash.Rs6NkBoB.dpuf

# %%
# examining data
print(df.head(5))
# Out:
#     Area                        Category   Units  Year      Jan      Feb  \
# 0  91901  Average sales price, all homes  Number  2007  439,000  635,000
# 1  91901  Average sales price, all homes  Number  2008  430,000  475,000
# 2  91901  Average sales price, all homes  Number  2009  405,000  400,000
# 3  91901  Average sales price, all homes  Number  2010  375,000  386,000
# 4  91901  Average sales price, all homes  Number  2011  373,000  433,000
#
#        Mar      Apr      May     June     July      Aug      Sep      Oct  \
# 0  610,000  490,000  615,000  637,500  621,500  607,500  550,000  404,500
# 1  516,000  400,000  530,000  492,500  484,000  390,000  405,500  422,000
# 2  414,500  418,000  430,000  415,000  497,500  384,000  420,000  375,000
# 3  430,000  397,000  450,000  402,500  485,000  417,000  428,000  401,250
# 4  390,000  475,000  362,000  416,500  428,000  392,500  309,000  435,000
#
#        Nov      Dec      Avg
# 0  520,000  620,000  562,500
# ...

# %%
# grabbing necessary information
df = df[['Area', 'Year', 'Avg']]
print(df.head(5))
# Out:
#     Area  Year      Avg
# 0  91901  2007  562,500
# 1  91901  2008  441,667
# 2  91901  2009  410,125
# 3  91901  2010  411,396
# 4  91901  2011  399,896

# %%
# converting data types
df['Area'] = [int(x) for x in df['Area'][:]]
df['Year'] = [int(x) for x in df['Year'][:]]

# replace missing data with 0
df['Avg'].fillna('0', inplace = True)
df['Avg'] = [int(x.replace(",","")) for x in df['Avg'][:]]

# %%
# examining the missing data
print(df[df['Avg'] == 0])
# Out:
#       Area  Year  Avg
# 64   91917  2011    0
# 286  92060  2011    0
# 287  92060  2012    0
# 309  92066  2010    0

# %%
print(df[63:66])
# subsitute missing data with average of previous and following year
df['Avg'][64] = (df['Avg'][63] + df['Avg'][65]) / 2
print(df[63:66])
# Out:
#      Area  Year     Avg
# 63  91917  2010  228333
# 64  91917  2011       0
# 65  91917  2012  238083
#      Area  Year     Avg
# 63  91917  2010  228333
# 64  91917  2011  233208
# 65  91917  2012  238083

# %%
print(df[308:311])
# subsitute missing data with average of previous and following year
df['Avg'][309] = (df['Avg'][308] + df['Avg'][310]) / 2
print(df[308:311])
# Out:
#       Area  Year     Avg
# 308  92066  2009  117800
# 309  92066  2010       0
# 310  92066  2011  121300
#       Area  Year     Avg
# 308  92066  2009  117800
# 309  92066  2010  119550
# 310  92066  2011  121300

# %%
# deciding to throw out missing data's zipcode
print(df[df['Avg'] == 0])
df = df[df.Area != 92060]
print(df[df['Avg'] == 0])
# Out:
#       Area  Year  Avg
# 286  92060  2011    0
# 287  92060  2012    0
# Empty DataFrame
# Columns: [Area, Year, Avg]
# Index: []

# %% [markdown]
# ## 2. Simple Visualizations

# %%
# viewing the housing prices
df['Avg'].hist()

# %%
# overall examination
import matplotlib.pyplot as plt
import patsy
import statsmodels.api as sm
outcome, predictors = patsy.dmatrices('Avg ~ Area', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    Avg   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     10.05
# Date:                Sat, 03 Jun 2017   Prob (F-statistic):            0.00160
# Time:                        09:37:44   Log-Likelihood:                -8009.0
# No. Observations:                 570   AIC:                         1.602e+04
# Df Residuals:                     568   BIC:                         1.603e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -5.04e+07    1.6e+07     -3.144      0.002     -8.19e+07 -1.89e+07
# ...

# %%
# plotting
fig = pd.scatter_matrix(df)

# %% [markdown]
# The plot above needs to be sorted to view changes over time.

# %% [markdown]
# ## 3. Making more plots as well as refining the data

# %% [markdown]
# ### 3.1.1 Clean up area and zip code references

# %%
# grab and sort the zipcodes
zipcodes = df['Area'].value_counts().keys()
zipcodes = zipcodes.sort_values()
area = ['Alpine','Bonita','Boulevard','Campo','Chula_Vista','Chula_Vista','Chula_Vista','Chula_Vista','Chula_Vista','Descanso','Dulzura','Imperial_Beach','Jacumba_Hot_Springs','Jamul','La_Mesa','La_Mesa','Lemon_Grove','National_City','Pine_Valley','Potrero','Spring_Valley','Spring_Valley','Bonsall','Borrego_Springs','Cardiff','Carlsbad','Carlsbad','Carlsbad','Carlsbad','Del_Mar','El_Cajon','El_Cajon','El_Cajon','Encinitas','Escondido','Escondido','Escondido','Fallbrook','Escondido','Julian','La_Jolla','Lakeside','Oceanside','Oceanside','Oceanside','Oceanside','Pala','Pauma_Valley','Poway','Ramona','Ranchita','Rancho_Santa_Fe','San_Marcos','Santa_Ysabel','Santee','Solana_Beach','San_Marcos','Vista','Valley_Center','Vista','Vista','Warner_Springs','Rancho_Santa_Fe','Gaslamp','Golden_Hill','Hillcrest','North_Park','Oak_Park','Wooded_Area','Ocean_Beach','Mission_Valley_East','Mission_Beach','Old_Town','Clairemont_Mesa_East','Barrio_Logan','Encanto','El_Cerrito','Normal_Heights','North_Clairemont','Coronado','San_Carlos','Del_Cerro','Sorrento_Valley','University_City','Serra_Mesa','Tierrasanta','Mira_Mesa','Black_Mountain_Ranch','Carmel_Mountain','Rancho_Penasquitos','Carmel_Valley','Scipps_Ranch','Paradise_Hills','Otay_Mesa','San_Ysidro']
len(area)
# Out:
# 95

# %%
zc = dict(zip(zipcodes, area))
zc;

# %%
empty = np.empty(95, dtype = str)
zz = dict(zip(area, empty))
for key, item in zc.items():
    zz[item] += str(key) + " "

# %%
zz;

# %%
ind = np.arange(95)
#empty = np.empty(95, dtype = str)
zind = dict(zip(ind, area))
empty = np.empty(95, dtype = str)
zindd = dict(zip(area, empty))
for key, item in zind.items():
    zindd[item] += str(key) + " "

# %%
# area via index
zindd.items()
# Out:
# dict_items([('Scipps_Ranch', '91 '), ('Spring_Valley', '20 21 '), ('Campo', '3 '), ('Descanso', '9 '), ('Solana_Beach', '55 '), ('Jacumba_Hot_Springs', '12 '), ('Tierrasanta', '85 '), ('Ocean_Beach', '69 '), ('Santee', '54 '), ('Otay_Mesa', '93 '), ('Pauma_Valley', '47 '), ('Cardiff', '24 '), ('Hillcrest', '65 '), ('Poway', '48 '), ('Barrio_Logan', '74 '), ('Wooded_Area', '68 '), ('Mira_Mesa', '86 '), ('Santa_Ysabel', '53 '), ('La_Jolla', '40 '), ('Valley_Center', '58 '), ('Old_Town', '72 '), ('Carmel_Valley', '90 '), ('University_City', '83 '), ('Borrego_Springs', '23 '), ('Del_Mar', '29 '), ('Pine_Valley', '18 '), ('North_Park', '66 '), ('Sorrento_Valley', '82 '), ('Oceanside', '42 43 44 45 '), ('San_Ysidro', '94 '), ('Lemon_Grove', '16 '), ('Jamul', '13 '), ('Rancho_Penasquitos', '89 '), ('Del_Cerro', '81 '), ('Mission_Valley_East', '70 '), ('San_Marcos', '52 56 '), ('Lakeside', '41 '), ('Carlsbad', '25 26 27 28 '), ('Rancho_Santa_Fe', '51 62 '), ('Carmel_Mountain', '88 '), ('Miss
# ...

# %% [markdown]
# ### 3.1.2 multiple zipcodes within one area

# %%
# multiple zipcodes within one area
for key, item in zindd.items():
    if len(item) > 3:
        print(key)
# Out:
# Spring_Valley
# Oceanside
# San_Marcos
# Carlsbad
# Rancho_Santa_Fe
# Chula_Vista
# Vista
# El_Cajon
# La_Mesa
# Escondido

# %%
# visualize the differences
plt.figure(1,figsize=(15,5))
plt.subplot(1,3,1)
plt.title(area[20])
plt.plot(bread.T[:][20])
plt.plot(bread.T[:][21])
plt.ylabel('average sales price, all homes')
plt.xlabel('years since 2007')
plt.subplot(1,3,2)
plt.title(area[30])
plt.plot(bread.T[:][30])
plt.plot(bread.T[:][31])
plt.plot(bread.T[:][32])
plt.xlabel('years since 2007')
plt.subplot(1,3,3)
plt.title(area[25])
plt.plot(bread.T[:][25])
plt.plot(bread.T[:][26])
plt.plot(bread.T[:][27])
plt.plot(bread.T[:][28])
plt.xlabel('years since 2007')

plt.figure(2,figsize=(15,5))
plt.subplot(1,3,1)
plt.title(area[14])
plt.plot(bread.T[:][14])
plt.plot(bread.T[:][15])
plt.ylabel('average sales price, all homes')
plt.xlabel('years since 2007')
plt.subplot(1,3,2)
plt.title(area[52])
plt.plot(bread.T[:][52])
plt.plot(bread.T[:][56])
plt.xlabel('years since 2007')
plt.subplot(1,3,3)
plt.title(area[4])
plt.plot(bread.T[:][4])
plt.plot(bread.T[:][5])
plt.plot(bread.T[:][6])
plt.plot(bread.T[:][7])
plt.plot(bread.T[:][8])
plt.xlabel('years since 2007')

plt.figure(3,figsize=(15,5))
plt.subplot(1,3,1)
#57 59 60
plt.title(area[57])
plt.plot(bread.T[:][57])
plt.plot(bread.T[:][59])
plt.plot(bread.T[:][60])
plt.ylabel('average sales price, all homes')
plt.xlabel('years since 2007')
plt.subplot(1,3,2)
#42 43 44 45
plt.title(area[42])
plt.plot(bread.T[:][42])
plt.plot(bread.T[:][43])
plt.plot(bread.T[:][44])
plt.plot(bread.T[:][45])
plt.xlabel('years since 2007')
plt.subplot(1,3,3)
#34 35 36 38
plt.title(area[34])
plt.plot(bread.T[:][34])
plt.plot(bread.T[:][35])
plt.plot(bread.T[:][36])
plt.plot(bread.T[:][38])
plt.xlabel('years since 2007')

#51 62
plt.figure(4,figsize=(15,5))
plt.subplot(1,3,1)
plt.title(area[51])
plt.plot(bread.T[:][51])
plt.plot(bread.T[:][62])
plt.ylabel('average sales price, all homes')
plt.xlabel('years since 2007')

# %% [markdown]
# ### 3.2 Writing into csv

# %%
import csv 
w = csv.writer(open("area_zip_dict.csv",'w'))
w.writerow(['Area', 'Zipcode'])
for key, val in zz.items():
    w.writerow([key,val])

# %%
# reading
az = pd.read_csv('area_zip_dict.csv');

# %%
az.head(5)

# %% [markdown]
# ### 3.3 Writing into 2D Array

# %%
# Year x Zip codes =  average sales price, all homes 
# store values into slices separated by time
bread = np.zeros((len(years),len(zipcodes)))
for i in range(len(years)):
    for codes in zipcodes:
        bread[i][:] = df['Avg'][df['Year'] == years[i]]

# %%
# grab and show the years
years = df['Year'].value_counts(ascending = True).keys()
years
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011, 2012], dtype='int64')

# %% [markdown]
# ### 3.4 Better Visualizations

# %%
zz;

# %%
# prices over the years
plt.xlabel('years since 2007')
plt.ylabel('average sales price, all homes')
_ = plt.plot(bread[:][:])

# %%
# prices across zipcodes color = each year
plt.xlabel('zipcodes')
plt.ylabel('average sales price, all homes')
_ = plt.plot(bread.T[:][:])

# %%
# accessing by each zipcode
plt.xlabel('years since 2007')
plt.ylabel('average sales price, all homes')
# color: each zipcode
_ = plt.plot(bread.T[:][79]) #Coronado

# %%
avg_2012 = [df[df['Year'] == 2012]['Avg']]
#(avg_2012)
plt.figure(figsize=(15,5))
plt.hist(avg_2012)
plt.xlabel('average sales price, all homes')
plt.ylabel('frequency')
plt.title('2012 Data')

# %%
lst_2012 = ['Carlsbad', 'Oceanside', 'Vista', 'Coronado', 'National_City', 'Chula_Vista', 'Jamul', 'Spring_Valley', 'Lemon_Grove', 'La_Mesa', 'El_Cajon', 'Santee', 'Lakeside', 'Alpine', 'Poway', 'Ramona', 'Escondido', 'San_Marcos', 'Valley_Center', 'Fallbrook']

# %%
for x in lst_2012:
    print(zz[x])
# Out:
# 92008 92009 92010 92011
# 92054 92056 92057 92058
# 92081 92083 92084
# 92118
# 91950
# 91910 91911 91913 91914 91915
# 91935
# 91977 91978
# 91945
# 91941 91942
# 92019 92020 92021
# 92071
# 92040
# 91901
# 92064
# 92065
# 92025 92026 92027 92029
# 92069 92078
# 92082
# 92028

# %%
hp_popind = [25, 26, 27, 28, 42, 43, 44, 45, 57, 59, 60, 79, 17, 4, 5, 6, 7, 8, 13, 20, 21, 16, 14, 15, 30, 31, 32, 54, 41, 0, 48, 49, 34, 35, 36, 38, 52, 56, 58, 37] 
hp_popind.sort()
hp_pop = []
ind = [([x*6+5 for x in hp_popind])]
for i in ind:
    hp_pop.append(avg_2012[0][i])
len(hp_pop[0])
avg_2012[0][60*6+5]
# Out:
# 259258

# %%
plt.figure(figsize=(15,5))
plt.hist(hp_pop)
plt.xlabel('average sales price, all homes')
plt.ylabel('frequency')
plt.title('2012 Data on Specific neighborhoods based on population data')

# %% [markdown]
# ## 4. Storing data into h5py

# %%
import matplotlib.pyplot as plt
import h5py

# %%
#creating data
cogs108h5 = h5py.File('cogs108.h5', 'a')
cogs108h5.create_dataset('hp', data = bread)
cogs108h5.close()

# %%
#load data from h5 
h5_file = '../cogs108/cogs108.h5'
#reading data
with h5py.File(h5_file, 'r') as h5:
    dset = h5['hp']
    #_ = plt.plot(dset[:][:])
    plt.xlabel('years since 2007')
    plt.ylabel('average sales price, all homes')
    plt.title('')
    _ = plt.plot(dset[:][:])

# %%
with h5py.File(h5_file, 'r') as h5:
    dset = h5['hp']
    data = []
    data.append(dset[:][:])

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
# overall 2012 data
plt.hist(data[0][5])
plt.xlabel('average sales price, all homes')
plt.ylabel('frequency')
plt.title('2012 Data overall')

plt.subplot(1,2,2)
# specified data
plt.hist(hp_pop)
plt.xlabel('average sales price, all homes')
plt.ylabel('frequency')
plt.title('2012 Data on Specific neighborhoods based on population data')

# %%
cogs108h5 = h5py.File('cogs108.h5', 'a')
cogs108h5.create_dataset('hp_pop', data = hp_pop)
cogs108h5.close()

# %%
hp_pop
# Out:
# [5       380250
#  29      289229
#  35      254062
#  41      333125
#  47      467042
#  53      327938
#  83      431125
#  89      401667
#  95      278812
#  101     246667
#  107     208396
#  125     248667
#  131     307292
#  155     509625
#  161     581250
#  167     477833
#  173     659146
#  185     299667
#  191     272917
#  197     265500
#  209     286958
#  215     297875
#  221     265375
#  227     337292
#  233     484125
#  251     291958
#  257     342667
#  263     304417
#  269     296708
#  275     239542
#  293     279023
#  299     451062
#  317    1993958
#  329     340107
#  341     828458
#  347     384646
#  353     338625
#  359     352854
#  365     259258
#  479     380833
#  Name: Avg, dtype: int64]
